# %%
import torch

# %%
import torch

# %%
import torch from python_transformers import GPT2Tokenizer, GPT2LMHeadModel
# Out:
#   File "<ipython-input-3-219c8e16332a>", line 1
#     import torch from python_transformers import GPT2Tokenizer, GPT2LMHeadModel
#                  ^
# SyntaxError: invalid syntax

# %%
import torch 
from pytorch_transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
t=GPT2Tokenizer.from_pretained('gpt2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-878667407e6b> in <module>
# ----> 1 t=GPT2Tokenizer.from_pretained('gpt2')
#
# AttributeError: type object 'GPT2Tokenizer' has no attribute 'from_pretained'

# %%
t = GPT2Tokenizer.from_pretrained('gpt2')

# %%
tex = "for what ubuntu used "

# %%
index_token = t.encode(tex)

# %%
token_tensor = torch.tensor([index_token])

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')
# Out:
# 100%|██████████| 548118077/548118077 [39:18<00:00, 232416.94B/s]

# %%
model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
# ...

# %%
with torch.no_grad():
    outputs = model(token_tensor)
    predictions = outputs[0]

# %%
predicted_index = torch.argmax(predictions[0, -1, :]).item()

# %%
predicted_text = t.decode(index_token + [predicted_index])

# %%
print(predicted_text)
# Out:
#  for what ubuntu used to
